# %%
import glob2
import pickle
import pandas as pd

# %%
# Setting up pathways
indir = "/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts"
outdir = "/Users/lerdp/Desktop/"
filenames = glob2.glob('%s/*.txt' %(indir))
filenames = filenames

# %%
name = filenames[0].strip(indir)
name = name[:len(name)-1]
name
# Out:
# '-0x8gTye-AI'

# %%
# Store file as dictionary
temp = {}
with open('combined.txt', 'w') as f:
    for file in filenames:
        name = file.strip(indir)
        name = name[:len(name)-1]
        with open(file) as infile:
            temp[name] = infile.read()

# %%
infile = open("subtitle.pkl",'rb')
new_dict = pickle.load(infile)

# %%
list(new_dict.keys())
# Out:
# ['-0x8gTye-AI.',
#  '-6p4H3jmF68.',
#  '-71ld0iqAq8.',
#  '-7OE2A2CCyY.',
#  '-7Ux2N38YvY.',
#  '-8DB5nkzBc4.',
#  '0-6lxT2HaAY.',
#  '0-JON5_KYYI.',
#  '0-VflJM4b3Q.',
#  '01zk9RZ7E7M.']

# %%
filenames
# Out:
# ['/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/-0x8gTye-AI.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/-6p4H3jmF68.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/-71ld0iqAq8.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/-7OE2A2CCyY.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/-7Ux2N38YvY.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/-8DB5nkzBc4.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/0-6lxT2HaAY.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/0-JON5_KYYI.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/0-VflJM4b3Q.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/01zk9RZ7E7M.txt',
#  '/Users/lerdp/Box/Peem ADA Project/Data/UnlabeledVideoTranscripts/03zVNKUwM98.txt',
# ...

# %%
filenames[0].strip(pwd)
# Out:
# '-0x8gTye-AI.'

# %%
# TODO: Handle .txt ending 
# TODO: Merge files
df = pd.DataFrame(index = list(temp.keys()), columns = ["subtitle"])
for index in df.index.tolist():
    df.loc[index, "subtitle"] = temp[index]

# %%
df
# Out:
#                                                        subtitle
# -0x8gTye-AI.  Hello, everybody. If this looks bad, stay tune...
# -6p4H3jmF68.
# -71ld0iqAq8.  Hello, welcome back to our Channel. Today. Our...
# -7OE2A2CCyY.  CC be there and promote imported. Also, this v...
# -7Ux2N38YvY.
# -8DB5nkzBc4.  Hey guys, it's dr. Sam Robbins. Now a lot of g...
# 0-6lxT2HaAY.  Dr. Pham will hear diabetes is increasing ever...
# 0-JON5_KYYI.  Hi, I'm Jen. And I'm a pharmacist today. We're...
# 0-VflJM4b3Q.  Hello, I'm sure okaasan. I am a pediatric endo...
# 01zk9RZ7E7M.  What are the different types of vitamins for d...

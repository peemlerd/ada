# %%
from helper_fn import *
import seaborn as sns

# %% [markdown]
# ## Downloading the following dataframes
#
# 1. df
# 2. df600
# 3. df_label: PEMAT-labelled dataset.
#
# NOTE: https:// creates problems with word_count distribution.

# %%
# NOTE: df should have 56 columns because we don't have labels on actionability, understandability, etc.
df = pd.read_csv("merged_and_cleaned12k.csv", sep = ",").dropna(how = "all").drop(columns = ["Unnamed: 0"])
df600 = pd.read_csv("merged_and_cleaned600.csv", sep = ",").drop(columns = ["Unnamed: 0"])
df_label = pd.read_csv("rawPEMAT.csv", sep = ",").drop(columns = ["Unnamed: 0"])
df_annotate = pd.read_csv("AnnotatedVideoFeatures.csv", sep = ",")

# %%
df600 = pd.merge(df600, df_annotate, how = "inner", left_on = "URL", right_on = "id", suffixes = [None, "f2"])

# %%
# Load the dictionary of PEMAT. 
# Plan: Work back and forth between the PEMAT raw file (df_label) and the cleaned file (df600).
f = open("PEMAT_dict.pkl","rb")
PEMAT_dict = pickle.load(f)

# %%
# Merge videos that appear multiple times under different keywords. 
groupby_column = 'video_id'
aggregate_column = 'keyword'
agg_df = df.groupby(groupby_column).aggregate({aggregate_column: list})
df_alias = df.drop(columns=aggregate_column).set_index(groupby_column)
agg_df = agg_df.join(df_alias).reset_index(groupby_column).drop_duplicates(groupby_column).reset_index(drop=True)
df = agg_df

# %%
dfcopy = df.copy()
# Out:
#          video_id                    keyword                  ARI  \
# 0     --3PG0yv7xo        [insulin sensitive]                 7.80
# 1     --GLJISL-sM           [glycogenolysis]                32.95
# 2     --KcUndJ7Tw              [Repaglinide]                 9.47
# 3     --P1IWDqESU  [End stage renal disease]                11.00
# 4     --Zx-67-FfY   [diabetic heart disease]                15.32
# ...           ...                        ...                  ...
# 8958  zxHEWa3J-I4       [glucose test strip]                15.71
# 8959  zxeKsGLpUEg         [pancreatic islet]                 2.26
# 8960  zyP82eAMVrU            [diabetic coma]                13.56
# 8961  zz-zF1w2WwY        [glucose tolerance]                 0.00
# 8962  zzWTCmWf2Xw           [glucose uptake]                12.03
#
#          FleshReadingEase              Kincaid          active_verb  \
# 0                   75.04                 6.54                91.00
# 1                  -24.82                26.66                 5.00
# 2                   48.64                 8.96                 2.00
# 3                   56.28                 8.69                 5.00
# 4                   37.55                14.14                27.00
# ...                   ...                  ...                  ...
# 8958                31.71                13.56                 3.00
# 8959               187.64               -11.17                 0.00
# 8960                77.04                11.21                 6.00
# 8961                 0.00                 0.00                 0.00
# 8962                61.89                 8.35                 7.00
#
#           has_description           id       sentence_count  \
# 0                    1.00  --3PG0yv7xo                44.00
# 1                    1.00  --GLJISL-sM                 3.00
# 2                    1.00  --KcUndJ7Tw                 2.00
# 3                    1.00  --P1IWDqESU                 5.00
# 4                    1.00  --Zx-67-FfY                 8.00
# ...                   ...          ...                  ...
# 8958                 1.00  zxHEWa3J-I4                 2.00
# 8959                 1.00  zxeKsGLpUEg                 1.00
# 8960                 1.00  zyP82eAMVrU                 1.00
# 8961                 0.00  zz-zF1w2WwY                 0.00
# 8962                 1.00  zzWTCmWf2Xw                 3.00
#
#             summary_words  ...    channelVideoCount  \
# 0                    0.00  ...               270.00
# 1                    0.00  ...               121.00
# 2                    0.00  ...             1,069.00
# 3                    0.00  ...            34,681.00
# 4                    0.00  ...             1,269.00
# ...                   ...  ...                  ...
# 8958                 0.00  ...               121.00
# 8959                 0.00  ...             1,025.00
# 8960                 0.00  ...            25,337.00
# 8961                 0.00  ...                16.00
# 8962                 0.00  ...                85.00
#
#       keyword_decription_cosine  comment_total_words  negative_comment_count  \
# 0                          0.24             1,381.00                    5.00
# 1                          0.16                23.00                    0.00
# 2                          0.00                 0.00                    0.00
# 3                          0.00                 0.00                    0.00
# 4                          0.04               463.00                    1.00
# ...                         ...                  ...                     ...
# 8958                       0.07                 0.00                    0.00
# 8959                       0.00                 0.00                    0.00
# 8960                       0.00                 0.00                    0.00
# 8961                       0.00                 0.00                    0.00
# 8962                       0.00                 0.00                    0.00
#
#      comment_description_cosine keyword_title_cosine  comment_title_cosine  \
# 0                          5.68                 0.14                  1.22
# 1                          0.11                 0.18                  0.00
# 2                          0.00                 0.21                  0.00
# 3                          0.00                 1.00                  0.00
# 4                          0.53                 0.17                  0.38
# ...                         ...                  ...                   ...
# 8958                       0.00                 0.36                  0.00
# 8959                       0.00                 0.31                  0.00
# 8960                       0.00                 0.36                  0.00
# 8961                       0.00                 0.61                  0.00
# 8962                       0.00                 0.23                  0.00
#
#      postive_comment_count comment_unique_words neutral_comment_count
# 0                    36.00             1,134.00                  5.00
# 1                     2.00                20.00                  0.00
# 2                     0.00                 0.00                  0.00
# 3                     0.00                 0.00                  0.00
# 4                     3.00               290.00                  1.00
# ...                    ...                  ...                   ...
# 8958                  0.00                 0.00                  0.00
# 8959                  0.00                 0.00                  0.00
# 8960                  0.00                 0.00                  0.00
# 8961                  0.00                 0.00                  0.00
# 8962                  0.00                 0.00                  0.00
#
# [8963 rows x 56 columns]

# %% [markdown]
# # PART 1: Descriptive Statistics
#
# First, I examined the features and classified them into three categories.
# 1. Video metadata
# 2. Video
# 3. Usage statistics
#
#
#
# **NOTE: See merge_and_cleaned for a description on the PEMAT labels. This is a descriptive statistics on the entire dataset.
#
# ## Useful resource
# 1. ARI: https://en.wikipedia.org/wiki/Automated_readability_index
# 2. Flesch reading ease:
# 3. Kincaid (formally titled: Flesch-Kincaid readability). https://readable.com/readability/flesch-reading-ease-flesch-kincaid-grade-level/
# 4. Cosine similarity: https://www.machinelearningplus.com/nlp/cosine-similarity/
#
# ## Appropriate ranges
# 1. ARI: 1-14
# 2. Kincaid: 0-19;
# 3. Flesch: 0-100.
# 4. cosine similarity -1 to 1;

# %%
# Checking the summary statistics for each of these features. 
fare = ["min", "max", "median", "mean", "std"]
temp = {}

# Labels
label = ["understand","action", "info"]

# Video metadata
readable = ['ARI', 'FleshReadingEase','Kincaid']

# Derivatives of video metadata
description_d = ["word_unique", "transition_words","summary_words","active_verb", "word_count", "sentence_count"]
keyword = ['keyword_title_cosine', 'keyword_decription_cosine']
channel = ['channelSubscriberCount', "channelViewCount", "channelCommentCount", "channelVideoCount"] # TODO: Log
duration = ["video_duration"] # Is already an integer
license = ["contentLicensed"]

# Miscellaneous
rank = ["rank"]
content = ["contentDefinition", "contentLicensed"]

# Usage statistics (outcome metrics)
like_dislike_view = ["likeCount", "dislikeCount", "viewCount"] # TODO: Log-transform
comment_cosine = ['comment_title_cosine', 'comment_description_cosine']
comment_d = ['commentCount','postive_comment_count','negative_comment_count','neutral_comment_count', 
           "comment_unique_words", "comment_total_words"]

# Group all variables in the dataframe: cateogrical or numerical 
dependent = label
numeric = readable + description_d + keyword + channel + duration + like_dislike_view + comment_cosine + comment_d
categoric = license + content
misc = rank

# %%
title = df600["channelTitle"].value_counts()

# %%
fig = boxplotVisualizer(df600, "understand", feature_lst = comment_d, title = "Readable")

# %%
# Summary statistics of Tables created in 2021. 
dependent = "action"
to_save600 = comparisonTable(df600, dependent, numeric).T
to_save600.to_csv("%s_summary.csv" %(dependent))
to_save8900 = summaryStatistics(df, numeric, fare = ["min", "max", "median", "mean", "std"]).T
to_save8900.to_csv("all_summary.csv")

# %%
# Plotting heatmap for correlation between two variables and labels
var_lst = ["readable", "description_d", "keyword", "channel", "duration", "like_dislike_view"]
var_lst += ["comment_cosine", "comment_d"]
var = var_lst[5]
title = "label_%s" %(like_dislike_view) + ".png"
cmap = sns.diverging_palette(20, 250, as_cmap=True)
fig, ax = plt.subplots(figsize = (12,8))
corr = df600[label + like_dislike_view].corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Building dataframe
ax = sns.heatmap(corr, cmap = cmap, mask=mask, vmin = -1, vmax = 1)
ax.set_title("Correlation between labels and %s." %(var))
fig.savefig(title)
# Out:
# /var/folders/4t/6j0632nj7bv5d1dkqdjmp3000000gn/T/ipykernel_83680/2113748802.py:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
# TODO: Like-dislike/viewCount ratio. 
dep_lst = ["understand", "action", "info"]
dependent = dep_lst[0]

feature_name = "channel"
title = "duration"
fig = boxplotVisualizer(df600, dependent, channel, title = title,
                        log_transform = True)
title = "boxplot_%s_%s" %(dependent,feature_name)
fig.savefig(title)

# %%
# Perform histogram of the dataset.
var = "channelVideoCount"
entire = True

if entire == True:
    x = df[var]
    name = "entire dataset"
else:
    x = df600[var]
    name = "labelled dataset"
bins = [2**i for i in range(7)]
fig = plt.hist(x, density = False, facecolor='b', alpha=0.75)
plt.xlabel('%s' %(var))
plt.ylabel('Number of videos')
plt.title('%s distribution on %s' %(var,name))
plt.grid(True)

# %%
# Check if columns of df600 and df are the same.
# Only difference: video_duration, understand, action, URL, which all appear in other forms already.
for col in df600.columns.tolist():
    if col not in df.columns.tolist():
        print(col)
# Out:
# URL
# Duration
# info
# action
# understand
# scene_count
# object_count
# idf2
# speech_confidence
# text_confidence
# sentence_countf2
# word_countf2
# word_uniquef2
# ARIf2
# Kincaidf2
# Flesch
# transition_wordsf2
# summary_wordsf2
# active_verbf2

# %% [markdown]
# # PART 2: Building models
# In this part, I used Kincaid as a response variable. The dataset is the miniature 600 versions whereby we have the labels. The logistic regression model is built upon only numerical values. Overall, the accuracy is egregiously high (80%), suggesting that I might overfit?

# %%
# Drop the indices with no_info. 
# Why: I have checked the data. These rows contains many NaN.
no_info = np.where(df600["info"].isna() == True)[0].tolist()
no_info += np.where(df600["viewCount"].isna() == True)[0].tolist()
no_count = np.where(np.isfinite(df600["sentence_count"]) == False)[0].tolist()
try:
    df600 = df600.drop(index = no_info+no_count)
    print("Row with no info and no sentence_count successfully dropped")
    df600 = df600.drop(columns = ["Unnamed: 0"])
    print("Dropping unnamed column.")
except:
    print("Columns already dropped")
# Out:
# Row with no info and no sentence_count successfully dropped
# Columns already dropped

# %%
# Truncate ARI to be from 0-14
ub = 14
lb = 0
truncateColumn(df600, lb, ub, "ARI")
# Out:
#              URL  Duration                 info  action  understand  \
# 0    -32U9eU1hdM       310                 1.00       0           1
# 1    -71ld0iqAq8       602                 1.00       0           1
# 2    -8HmZjScLe0       732                 0.00       0           0
# 3    -Aj5BTnz-v0       559                 1.00       1           1
# 4    -IaysvX1L8U       246                 1.00       0           1
# ..           ...       ...                  ...     ...         ...
# 568  zLbAxztnnfE       163                 0.00       0           0
# 569  zPdwsCTp4gM       751                 1.00       0           1
# 570  zU-5GcqzHNM       819                 1.00       1           1
# 571  z_3S2_41_FE       300                 1.00       0           1
# 572  zsVRO4IZoFw       171                 0.00       1           1
#
#                      ARI     FleshReadingEase              Kincaid  \
# 0                  14.00                28.51                13.75
# 1                   9.06                52.87                 8.75
# 2                  14.00                70.67                10.03
# 3                  14.00                25.99                13.21
# 4                  12.51                45.13                11.97
# ..                   ...                  ...                  ...
# 568                14.00                19.81                16.74
# 569                 8.49                65.03                 7.58
# 570                14.00                62.72                12.56
# 571                 9.27                75.98                 7.75
# 572                14.00                29.53                17.97
#
#              active_verb      has_description  ...      text_confidence  \
# 0                  59.00                 1.00  ...                 0.87
# 1                  31.00                 1.00  ...                 0.85
# 2                  42.00                 1.00  ...                 0.79
# 3                  23.00                 1.00  ...                 0.80
# 4                  16.00                 1.00  ...                 0.96
# ..                   ...                  ...  ...                  ...
# 568                77.00                 1.00  ...                 0.90
# 569                 6.00                 1.00  ...                 1.00
# 570                17.00                 1.00  ...                 0.88
# 571                32.00                 1.00  ...                 0.93
# 572               119.00                 1.00  ...                 0.89
#
#      sentence_countf2  word_countf2  word_uniquef2                ARIf2  \
# 0                  26           635            311                16.56
# 1                  36          1241            449                19.28
# 2                 107          1883            502                 5.61
# 3                  79          1861            409                 8.87
# 4                  26           599            282                13.29
# ..                ...           ...            ...                  ...
# 568                24           349            166                10.54
# 569                87          1806            650                10.42
# 570               109          1890            650                 7.80
# 571                61           786            370                 5.25
# 572                32           262            136                 4.83
#
#                Kincaidf2               Flesch transition_wordsf2  \
# 0                  16.22                22.30                 14
# 1                  16.28                39.73                 14
# 2                   5.03                90.36                 21
# 3                   7.70                81.82                 17
# 4                  13.02                42.78                 11
# ..                   ...                  ...                ...
# 568                10.16                48.09                  8
# 569                 9.64                62.89                 20
# 570                 7.26                73.93                 24
# 571                 4.72                84.19                 13
# 572                 4.76                75.50                  3
#
#     summary_wordsf2  active_verbf2
# 0                 0             81
# 1                 0            170
# 2                 0            463
# 3                 0            309
# 4                 0            104
# ..              ...            ...
# 568               0             39
# 569               1            301
# 570               0            364
# 571               0            124
# 572               0             43
#
# [573 rows x 74 columns]

# %% [markdown]
# # ChannelLevel Analysis
#
# **NOTE: We have removed videos appearing twice under different keywords.**
# There are $8,963$ videos, appearing in $5,322$ channels. Interestingly, there are $3,304$ videos with more than $5,000$ views (from now, I call them relevant), appearing in $2,186$ channels. Hence, there are $3,000$ channels responsible for $5,600$ videos (i.e., these channels appear only 1.9 times among many keyword search related to diabetes).
#
# Findings:
# 1. Top 1% channel (ranked by number of videos in this dataset) produces $1,276$ (14%) of the videos but only $10%$ of the views. Almost 60% of the videos are created only from 20% of the channels. See the cumulative plot.
# 2. After top 20%, the remaining videos are created by one channel per one video, as suggested by the slope almost equal to 53/89 (1 video per 1 channel; 53 channel = 1% >> 53 video = 53/89%).
# 3. The step-wise nature of the percentView, percentLike, etc. suggests clear outliers.
# My thoughts on viewCount analysis:
#
# 1. It's suspicious that their videos appear only once or twice given that we use so many keywords related to diabetes. However, their title is sometimes relevant (yoga video // glyocosis vs glycogenesis ..), but the channelVideoCount looks very sketchy >> If they have many videos, but many of their videos are not related to diabetes, maybe they are not experts on diabetes.
# 2. Classifying misinformation based on views is not a great idea, I think.

# %%
# Create a list of videos that dominate the viewCounts, likeCounts, dislikeCounts
var = "viewCount"
thresh = sum(df[var])*0.01
list3 = df[df[var] > thresh][["viewCount","likeCount","dislikeCount", "title"]].index
df[df[var] > thresh][["viewCount","likeCount","dislikeCount", "title", 'channelTitle']]
# Out:
#       viewCount  likeCount  dislikeCount  \
# 569   369970829    2422615         80887
# 821    24097435    2146177        212994
# 1016  144488302     231355         16209
# 1284   46618529     252325         18206
# 2425   21256698      95461         16825
# 3265   82532868     424508         11830
# 4016   40268477     202677          4806
# 5648   20146716      70514         13942
# 8940  226092625    2231006        149924
#
#                                                   title          channelTitle
# 569   First Of The Year (Equinox) - Skrillex [OFFICIAL]              Skrillex
# 821              THESE GLASSES CURED MY COLORBLINDNESS!      Logan Paul Vlogs
# 1016  Banda El Recodo De Cruz Lizárraga - Consecuenc...     BandaElRecodoVEVO
# 1284                The Most UNEXPECTED Auditions EVER!        MusicTalentNow
# 2425  Miguelito tiene novia - Morandé con Compañía 2016          MEGA Oficial
# 3265                  Earth, Wind & Fire - Let's Groove  EarthWindandFireVEVO
# 4016  Frank Medrano - Superhuman Bodyweight Workout ...         Frank Medrano
# 5648  Miguelito aprende zumba con sensual instructor...          MEGA Oficial
# 8940  MC Kevinho - Tô Apaixonado Nessa Mina (KondZilla)       Canal KondZilla

# %%
dominator = list3
df = df.drop(index = dominator)

# %%
# There are 5300 channels in total. I define top channels as the channels creating most videos in this dataset
# 1. All about diabetes
# 2. Dr. Eric Berg DC
ntop = [int(nchannel/100)*i for i in range(1,100,1)] # Number of top channels
nvideo = df.shape[0]
channel_toplst = [df["channelTitle"].value_counts().head(X).index for X in ntop] # Name of top X channels. 

# Plot of cumulative values for like_dislike_view. 
cumulative = []
for var in like_dislike_view:
    temp = [(sum(df[df["channelTitle"].isin(channel_top)][var])/sum(df[var]))*100
                   for channel_top in channel_toplst] # The Top X channels account for how many views
    cumulative.append(temp)
percentLike = cumulative[0]
percentDislike = cumulative[1]
percentView = cumulative[2]

# The Top X channels account for how many views
percentVideo = [(df[df["channelTitle"].isin(channel_top)].shape[0]/df.shape[0])*100 for channel_top in channel_toplst]

# %%
# Check index of outsized videos
index = 87
temp = df[df["channelTitle"].isin([channel for channel in channel_toplst[index+1] 
                                           if channel not in channel_toplst[index]])]
temp[["viewCount","likeCount","dislikeCount"]]
# Out:
#       viewCount  likeCount  dislikeCount
# 347        1140         93             0
# 353        2215          9             0
# 354       35582        192             7
# 355        2309         16             1
# 356        2222         12             1
# 359          98         22             0
# 361        9770         43             9
# 369        7674         19             1
# 4293          9          0             0
# 4295       3680          5             2
# 4297       1025         26             0
# 4299      16995         36             2
# 4302        131          0             0
# 4304     212342        704           189
# 4305        207          0             0
# 4307       2738         24             4
# 4308          0          0             0
# 4309         47          0             0
# 4310     366930       1548           141
# 4311         77          0             0
# 4314       9773         41             8
# 4340        140          3             0
# 4347         37          0             0
# 4350        214          0             0
# 4351        652        188             1
# 4354      44154         16             6
# 4355        347          3             0
# 4357     159564       3572            72
# 4359       2155          9             0
# 4360       5741         13             1
# 4361      21854        118             1
# 4362        147          1             0
# 4363      17374         50             3
# 4367      28163        284            13
# 4371        254         13             0
# 4373       1676        108            15
# 4378        870         29             1
# 4380        264          1             0
# 4387         47          0             0
# 4392       1070         12             0
# 4396     374047       2018           249
# 4401        379          0             0
# 4402         36          4             0
# 4403        625          1             0
# 4405      14803         75             4
# 4406         85          0             0
# 4410      56762        502            16
# 4520     743231       4868           306
# 4523       8017         29             1
# 4699       1027          7             0
# 4701      15003         76             0
# 4702      15319         27             4
# 4703       4588         21             1

# %%
# Figure 1: Cumulative plots of like-dislike-view suggest some outliers
# NOTE: Polarizing? Keyword: Adult blindness. Title: THESE GLASSES CURED MY COLORBLINDNESS! by Logan Paul. 
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(np.arange(1,100,1), percentLike, label = "Percent Like", color = "green")
ax.plot(np.arange(1,100,1), percentDislike, label = "Percent Dislike", color = "red")
ax.plot(np.arange(1,100,1), percentView, label = "Percent View", color = "black")
ax.plot(np.arange(1,100,1),np.arange(1,100,1), marker = ".",label = "Y=X", color = "gray", alpha = 0.5)
plt.title("Cumulative plots of like-dislike-view suggest some outliers.")
ax.set_xlabel('Percent of top channels')
ax.set_ylabel('Cumulative percent')
ax.legend()

# %%
# Figure 2: The majority of videos are created from few channels
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(np.arange(1,100,1), percentVideo, label = "Percent Video", color = "blue")
ax.plot(np.arange(1,100,1),np.arange(1,100,1), marker = ".",label = "Y=X", color = "gray", alpha = 0.5)
plt.title("The majority of videos are created from few channels.")
ax.set_xlabel('Percent of top channels')
ax.set_ylabel('Cumulative percent')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(np.arange(1,100,1), percentLike, label = "Percent Like", color = "green")
ax.plot(np.arange(1,100,1), percentDislike, label = "Percent Dislike", color = "red")
ax.plot(np.arange(1,100,1), percentView, label = "Percent View", color = "black")
ax.plot(np.arange(1,100,1),np.arange(1,100,1), marker = ".",label = "Y=X", color = "gray", alpha = 0.5)
ax.plot(np.arange(1,100,1), percentVideo, label = "Percent Video", color = "blue")
plt.title("Top channels are not viewed that often (see blue above rest)")
ax.set_xlabel('Percent of top channels')
ax.set_ylabel('Cumulative percent')
ax.legend()

# %%
channel_top = df["channelTitle"].value_counts().head(50)
sum(channel_top)
# Out:
# 1240

# %%
df["viewCount"]
# Out:
# 0        9347
# 1        1972
# 2         256
# 3          59
# 4       23507
#         ...
# 8958     3198
# 8959        3
# 8960     2177
# 8961       58
# 8962     2091
# Name: viewCount, Length: 8963, dtype: int64

# %%
sum(df["viewCount"])
# Out:
# 2008235592

# %%
df["channelTitle"].value_counts().head(53).index.tolist()
# Out:
# ['All About Diabetes and Related',
#  'Dr. Eric Berg DC',
#  'Pronunciation Guide',
#  'RxWikiTV',
#  'Tony PharmD',
#  'Question Box',
#  'diabetesmadeeasier',
#  "Doctors' Circle - Ask Doctors. Free Video Answers.",
#  'Diabetes.co.uk',
#  'Emma Saying',
#  'But But But',
#  'botcaster inc. bot',
#  'khanacademymedicine',
#  'Diabetes Healthy Living Channel',
#  'TEDx Talks',
#  'MD Magazine',
#  'MEGA Oficial',
#  'manjanest',
#  'sparky BUBBLES',
#  'RegisteredNurseRN',
#  'John Eliott',
#  'Medical Symptom Information',
#  'Armando Hasudungan',
#  'AK LECTURES',
#  'Joe Prendergast',
#  'diabetes lecture',
#  'Free Diabetes & Health',
#  'Diabetes zone',
#  'Osmosis',
#  'ehowhealth',
#  "Shomu's Biology",
#  'AJMCtv',
#  'Dr. John Campbell',
#  'DrER.tv',
#  'Audiopedia',
#  'I Question You',
#  'Aspart Punkrock',
#  'NutritionFacts.org',
#  'Thomas DeLauer',
#  'Ford Brewer',
#  'Orange Health',
#  'International Association of Privacy Professionals',
#  'DiabeticDanica',
#  'Khan Academy',
#  'Taking Control Of Your Diabetes',
#  'Dr. Richard K. Bernstein',
#  'diabetes cure',
#  "Starlix Sans's gf",
#  'Medical Dictionary Online',
#  'Rajeev Ranjan Gupta',
#  'University of California Television (UCTV)',
#  'dailyRx',
#  'RukDo']

# %%
df.columns.tolist()
# Out:
# ['video_id',
#  'keyword',
#  'ARI',
#  'FleshReadingEase',
#  'Kincaid',
#  'active_verb',
#  'has_description',
#  'id',
#  'sentence_count',
#  'summary_words',
#  'transition_words',
#  'video_duration',
#  'word_count',
#  'word_unique',
#  'captsLastUpdated',
#  'contentDefinition',
#  'channelViewCount',
#  'relevantTopicIds',
#  'captid',
#  'title',
#  'topicIds',
#  'channelSubscriberCount',
#  'contentLicensed',
#  'channelCommentCount',
#  'categoryId',
#  'viewCount',
#  'contentCaption',
#  'channelId',
#  'likeCount',
#  'license',
#  'rank',
#  'contentDimension',
#  'contentDuration',
#  'embeddable',
#  'publicStatsViewable',
#  'channelPublishedat',
#  'isAutoSynced',
#  'trackKind',
#  'subtitle',
#  'channelTitle',
#  'comment',
#  'dislikeCount',
#  'publishedAt',
#  'channelDescription',
#  'commentCount',
#  'description',
#  'channelVideoCount',
#  'keyword_decription_cosine',
#  'comment_total_words',
#  'negative_comment_count',
#  'comment_description_cosine',
#  'keyword_title_cosine',
#  'comment_title_cosine',
#  'postive_comment_count',
#  'comment_unique_words',
#  'neutral_comment_count']

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:20,.2f}'.format
import matplotlib.pyplot as plt
import string
import random

# Statistics library
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
from sklearn.metrics import roc_curve, roc_auc_score

# Downloading NLP library
import re
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords

# %%
df600 = pd.read_csv("merged_and_cleaned600.csv", sep = ",").drop(columns = ["Unnamed: 0"])
df600 = df600[df600["subtitle"] != "[]"]

stopword_lst = list(set(stopwords.words('english')))
stopword_lst += ["nof","nthe"]

# %%
df600[["subtitle", "id"]]
# Out:
#                                               subtitle           id
# 0    ['Hyperkalemia refers to abnormally high level...  -32U9eU1hdM
# 1    ['Hello.. Welcome back to our channel.Today ou...  -71ld0iqAq8
# 3    ['What I wanted to do in this video is familia...  -Aj5BTnz-v0
# 4    ['Hi this is Dr K from imedicalschool and toda...  -IaysvX1L8U
# 10   ['The most basic function of bodily fat\nis se...  -vNVG7XJpVE
# ..                                                 ...          ...
# 616  ['Thyroid disorders and diabetes thyroid\ndiso...  zLbAxztnnfE
# 617  ['Hi everyone, my name is Pat Hartley-Gibson\n...  zPdwsCTp4gM
# 618  ['Translator: Joseph Geni\nReviewer: Joanna Pi...  zU-5GcqzHNM
# 619  ['These are my assistants, Coleman and Phil.Th...  z_3S2_41_FE
# 620  ['are you suffering with diabetes from\nlongti...  zsVRO4IZoFw
#
# [462 rows x 2 columns]

# %%
# TODO: Define a cleaner function.
# Account for 
"kidneysand".strip("and")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4t/6j0632nj7bv5d1dkqdjmp3000000gn/T/ipykernel_89287/2152973846.py in <module>
# ----> 1 "kidneysand".strip("and", "or")
#
# TypeError: strip expected at most 1 arguments, got 2

# %%
df600["subtitle"].iloc[0].split("\\n")
# Out:
# ["['Hyperkalemia refers to abnormally high levels",
#  'of potassium in the blood.In normal circumstances, more than 90% of',
#  'the total body potassium is INTRAcellular;the remaining is in the EXTRAcellular fluid',
#  'and blood plasma.The ratio of INTRAcellular to EXTRAcellular',
#  'potassium is important for generation of actionpotentials and is essential for normal functions',
#  'of neurons, skeletal muscles and cardiac muscles.This is why potassium levels in the blood',
#  'are strictly regulated within a narrow rangebetween 3.5 and 5mmol/L. As the normal daily',
#  'dietary intake of potassium varies widelyand can be as much as 100mmol a day, the body',
#  'must quickly and precisely react to keep bloodpotassium levels within the normal limits.This is achieved by 2 mechanisms:',
#  '- Excretion of potassium through the kidneysand intestines; with the kidneys playing a',
#  'predominant role.- Shifting of potassium from the extracellular',
# ...

# %%
[item for item in simple_preprocess(df600["subtitle"].iloc[0]) if item not in stopword_lst]
# Out:
# ['hyperkalemia',
#  'refers',
#  'abnormally',
#  'high',
#  'levels',
#  'potassium',
#  'blood',
#  'normal',
#  'circumstances',
#  'total',
#  'body',
#  'potassium',
#  'intracellular',
#  'remaining',
#  'extracellular',
#  'fluid',
#  'nand',
#  'blood',
#  'plasma',
#  'ratio',
#  'intracellular',
#  'extracellular',
#  'npotassium',
#  'important',
#  'generation',
#  'essential',
#  'normal',
#  'functions',
#  'neurons',
#  'skeletal',
#  'muscles',
#  'cardiac',
#  'muscles',
#  'potassium',
#  'levels',
#  'blood',
#  'nare',
#  'strictly',
#  'regulated',
#  'within',
#  'narrow',
#  'rangebetween',
#  'mmol',
#  'normal',
#  'daily',
#  'ndietary',
#  'intake',
#  'potassium',
#  'varies',
#  'widelyand',
#  'much',
#  'mmol',
#  'day',
#  'body',
#  'nmust',
#  'quickly',
#  'precisely',
#  'react',
#  'keep',
#  'bloodpotassium',
#  'levels',
#  'within',
#  'normal',
#  'limits',
#  'achieved',
#  'mechanisms',
#  'excretion',
#  'potassium',
#  'kidneysand',
# ...

# %%
df600["subtitle"].iloc[0]
# Out:
# "['Hyperkalemia refers to abnormally high levels\\nof potassium in the blood.In normal circumstances, more than 90% of\\nthe total body potassium is INTRAcellular;the remaining is in the EXTRAcellular fluid\\nand blood plasma.The ratio of INTRAcellular to EXTRAcellular\\npotassium is important for generation of actionpotentials and is essential for normal functions\\nof neurons, skeletal muscles and cardiac muscles.This is why potassium levels in the blood\\nare strictly regulated within a narrow rangebetween 3.5 and 5mmol/L. As the normal daily\\ndietary intake of potassium varies widelyand can be as much as 100mmol a day, the body\\nmust quickly and precisely react to keep bloodpotassium levels within the normal limits.This is achieved by 2 mechanisms:\\n- Excretion of potassium through the kidneysand intestines; with the kidneys playing a\\npredominant role.- Shifting of potassium from the extracellular\\nfluid into the cells by the sodium/potassiumpump.The pump is mainly regulate
# ...
